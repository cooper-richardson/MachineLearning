# %%
import pandas as pd

# Load the Titanic dataset if it's not already
df = pd.read_csv("Titanic Dataset.csv")

print("✓ Data loaded successfully!")
print(f"Original shape: {df.shape}")
print(f"\nOriginal columns: {df.columns.tolist()}")
# Out:
# ✓ Data loaded successfully!
# Original shape: (1309, 14)
#
# Original columns: ['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest']

# %%
# TODO: Print the shape of the DataFrame
print(f"Rows: {len(df)}")
print(f"Columns: {len(df.columns)}")
# Out:
# Rows: 1309
# Columns: 14

# %%
# TODO: Use .head() to display the first 5 rows
print(df.head)
# Out:
# <bound method NDFrame.head of       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0     female  29.00      0      0   24160  211.3375       B5        S    2
# 1       male   0.92      1      2  113781  151.5500  C22 C26        S   11
# 2     female   2.00      1      2  113781  151.5500  C22 C26        S  NaN
# 3       male  30.00      1      2  113781  151.5500  C22 C26        S  NaN
# 4     female  25.00      1      2  113781  151.5500  C22 C26        S  NaN
# ...      ...    ...    ...    ...     ...       ...      ...      ...  ...
# 1304  female  14.50      1      0    2665   14.4542      NaN        C  NaN
# 1305  female    NaN      1      0    2665   14.4542      NaN        C  NaN
# 1306    male  26.50      0      0    2656    7.2250      NaN        C  NaN
# 1307    male  27.00      0      0    2670    7.2250      NaN        C  NaN
# 1308    male  29.00      0      0  315082    7.8750      NaN        S  NaN
#
#        body                        home.dest
# 0       NaN                     St Louis, MO
# 1       NaN  Montreal, PQ / Chesterville, ON
# 2       NaN  Montreal, PQ / Chesterville, ON
# 3     135.0  Montreal, PQ / Chesterville, ON
# 4       NaN  Montreal, PQ / Chesterville, ON
# ...     ...                              ...
# 1304  328.0                              NaN
# 1305    NaN                              NaN
# 1306  304.0                              NaN
# 1307    NaN                              NaN
# 1308    NaN                              NaN
#
# [1309 rows x 14 columns]>

# %%
# TODO: Use .isnull().sum() to count missing values per column
print(f"Missing values in original data: {df.isnull().sum()}")
# Out:
# Missing values in original data: pclass          0
# survived        0
# name            0
# sex             0
# age           263
# sibsp           0
# parch           0
# ticket          0
# fare            1
# cabin        1014
# embarked        2
# boat          823
# body         1188
# home.dest     564
# dtype: int64

# %%
# Most missing values is Body

# %%
# TODO: Select only the useful columns
# Hint: df = df[['column1', 'column2', ...]]
df = df[['pclass', 'survived', 'sex', 'age', 
         'sibsp', 'parch', 'fare', 'embarked']]

print("✓ Columns selected!")
print(f"New shape: {df.shape}")
print(f"\nColumns: {df.columns.tolist()}")
# Out:
# ✓ Columns selected!
# New shape: (1309, 8)
#
# Columns: ['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch', 'fare', 'embarked']

# %%
# We dropped the Name, Cabin, and Boat columns as they would have no impact on survival

# %%
# TODO: Check for missing values in the cleaned dataset
print(f"Missing values after feature selection: {df.isnull().sum()}")
# Out:
# Missing values after feature selection: pclass        0
# survived      0
# sex           0
# age         263
# sibsp         0
# parch         0
# fare          1
# embarked      2
# dtype: int64

# %%
# There are 263 missing values in the age column
# There is 1 missing value in the fare column
# There are 2 missing values in the embarked column

# %%
# TODO: Calculate the median age
median_age = df['age'].median()
print(f"Median age: {median_age}")
# Out:
# Median age: 28.0

# %%
# TODO: Fill missing ages with median_age
# Hint: Use .fillna(value, inplace=True)
df['age'].fillna(median_age, inplace=True)

print("✓ Missing ages filled with median!")
print(f"Missing ages now: {df['age'].isnull().sum()}")
# Out:
# ✓ Missing ages filled with median!
# Missing ages now: 0
# C:\Users\mc_crichardson26\AppData\Local\Temp\ipykernel_89328\1387503979.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(median_age, inplace=True)

# %%
# Calculate both median and mean
print(f"Median age: {df['age'].median():.2f}")
print(f"Mean age: {df['age'].mean():.2f}")
# Out:
# Median age: 28.00
# Mean age: 29.50

# %%
# The mean is larger because the mean includes outlying values while the median is solely the middle value

# %%
# TODO: Calculate median fare
median_fare = df['fare'].median()
print(f"Median fare: ${median_fare:.2f}")

# TODO: Fill missing fare with median
df['fare'].fillna(median_fare, inplace=True)

print("✓ Missing fare filled!")
print(f"Missing fares now: {df['fare'].isnull().sum()}")
# Out:
# Median fare: $14.45
# ✓ Missing fare filled!
# Missing fares now: 0
# C:\Users\mc_crichardson26\AppData\Local\Temp\ipykernel_89328\1103339700.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['fare'].fillna(median_fare, inplace=True)

# %%
rows_before = len(df)
print(f"Rows before dropping: {rows_before}")
# Out:
# Rows before dropping: 1309

# %%
# TODO: Drop rows where 'embarked' is missing
# Hint: Use .dropna(subset=['column_name'], inplace=True) - also in the lesson material
df.dropna(subset=['embarked'], inplace=True)

rows_after = len(df)
rows_dropped = rows_before - rows_after

print("✓ Rows with missing embarked dropped!")
print(f"Rows after dropping: {rows_after}")
print(f"Rows dropped: {rows_dropped}")
print(f"Missing embarked now: {df['embarked'].isnull().sum()}")
# Out:
# ✓ Rows with missing embarked dropped!
# Rows after dropping: 1307
# Rows dropped: 2
# Missing embarked now: 0

# %%
# We lost .153% of data by dropping these rows

# %%
# TODO: Check for any remaining missing values
print("Final missing value check:")
print(df.isnull().sum())
print(f"\nTotal missing values: {df.isnull().sum().sum()}")
# Out:
# Final missing value check:
# pclass      0
# survived    0
# sex         0
# age         0
# sibsp       0
# parch       0
# fare        0
# embarked    0
# dtype: int64
#
# Total missing values: 0

# %%
# There are not any missing values

# %%
# Display summary statistics
print("Summary statistics after cleaning:")
df.describe()
# Out:
# Summary statistics after cleaning:
#             pclass     survived          age        sibsp        parch  \
# count  1307.000000  1307.000000  1307.000000  1307.000000  1307.000000
# mean      2.296863     0.381025    29.471821     0.499617     0.385616
# std       0.836942     0.485825    12.881592     1.042273     0.866092
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    22.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    35.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare
# count  1307.000000
# mean     33.209595
# std      51.748768
# min       0.000000
# 25%       7.895800
# 50%      14.454200
# 75%      31.275000
# max     512.329200

# %%
# The average age after filling missing values is 29
# The average fare is 33

# %%
# Save cleaned data
# Writes the DataFrame to a new CSV file without adding extra row numbers (index)
df.to_csv("Titanic_Cleaned.csv", index=False)     

# Prints a confirmation message so the user knows the save was successful
print("✓ Cleaned data saved to 'Titanic_Cleaned.csv'")
# Out:
# ✓ Cleaned data saved to 'Titanic_Cleaned.csv'

# %%
# It is important to check for missing values so the model is accurate
# Missing values should be filled in when there is a small amount of missing values. It should be dropped when there us a large amount of missing values
# We used median to fill in missing ages as median does not include outliers as much as mean
# If a model was trained with missing values it would likely be highly inaccurate 
# Missing data might occur in a situation where certain people did not have their age recorded
